# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
def extract_tesda_data():
    tesda_df = pd.read_csv('tesda_institutions.csv')
    tesda_df = tesda_df.drop_duplicates(subset='name_of_institution')
    tesda_df = tesda_df.region.value_counts().reset_index(name='tesda_accredited_institutions')
    tesda_df = tesda_df.rename(columns={'index':'region'})
    return tesda_df

# %%
tesda_df = extract_tesda_data()

# %%
income_df = pd.merge(income_df, tesda_df, on='region')
corr = income_df.corr()
# Make figure size larger
sns.set(rc={'figure.figsize':(11.7,8.27)})

# using seaborn to plot the correlation heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')
# Out:
# <AxesSubplot:>

# %%
income_df.columns
# Out:
# Index(['total_household_income', 'region', 'total_food_expenditure',
#        'main_income_source', 'agricultural_indicator',
#        'Bread and Cereals Expenditure', 'Total Rice Expenditure',
#        'Meat Expenditure', 'Total Fish and  marine products Expenditure',
#        'Fruit Expenditure', 'Vegetables Expenditure',
#        'Restaurant and hotels Expenditure', 'Alcoholic Beverages Expenditure',
#        'tobacco_expenditure', 'clothings_expenditure',
#        'housing_and_water_expenditure', 'Imputed House Rental Value',
#        'medical_care_expenditure', 'Transportation Expenditure',
#        'Communication Expenditure', 'education_expenditure',
#        'Miscellaneous Goods and Services Expenditure',
#        'Special Occasions Expenditure', 'Crop Farming and Gardening expenses',
#        'Total Income from Entrepreneurial Acitivites', 'house_hold_sex',
#        'household_head_age', 'house_hold_head_marital_status',
#        'household_head_highest_grade', 'household_head_job_business_indicator',
#        'Household Head Occupation', 'Household Head Class of Worker',
#        'type_of_household', 'family_members',
#        'Members with age less than 5 year old',
#        'Members with age 5 - 17 years old', 'employed_family_members',
#        'Type of Building/House', 'Type of Roof', 'Type of Walls',
#        'House Floor Area', 'House Age', 'Number of bedrooms', 'Tenure Status',
#        'Toilet Facilities', 'Electricity', 'Main Source of Water Supply',
#        'Number of Television', 'Number of CD/VCD/DVD',
#        'Number of Component/Stereo set', 'Number of Refrigerator/Freezer',
#        'Number of Washing Machine', 'Number of Airconditioner',
#        'Number of Car, Jeep, Van', 'Number of Landline/wireless telephones',
#        'Number of Cellular phone', 'Number of Personal Computer',
#        'Number of Stove with Oven/Gas Range', 'Number of Motorized Banca',
#        'Number of Motorcycle/Tricycle', 'tesda_accredited_institutions'],
#       dtype='object')

# %%
column_names = [
    'total_household_income',
    'region',
    'total_food_expenditure',
    'main_income_source',
    'agricultural_indicator',
    'tobacco_expenditure',
    'clothings_expenditure',
    'housing_and_water_expenditure',
    'medical_care_expenditure',
    'education_expenditure',
    'house_hold_sex',
    'household_head_age',
    'house_hold_head_marital_status',
    'household_head_highest_grade',
    'household_head_job_business_indicator',
    'type_of_household',
    'family_members',
    'employed_family_members',
    'tesda_accredited_institutions', ]
income_df = income_df[column_names]
# Out:
#    total_household_income region  total_food_expenditure main_income_source  \
# 0                  480332    CAR                  117848      Wage/Salaries
# 1                  198235    CAR                   67766      Wage/Salaries
# 2                   82785    CAR                   61609      Wage/Salaries
# 3                  107589    CAR                   78189      Wage/Salaries
# 4                  189322    CAR                   94625      Wage/Salaries
#
#    agricultural_indicator  tobacco_expenditure  clothings_expenditure  \
# 0                       0                    0                   4607
# 1                       0                 2132                   8230
# 2                       1                 4525                   2735
# 3                       0                    0                   1390
# 4                       0                    0                   4620
#
#    housing_and_water_expenditure  medical_care_expenditure  \
# 0                          63636                      3457
# 1                          41370                      3520
# 2                          14340                        70
# 3                          16638                        60
# 4                          31122                       140
#
#    education_expenditure house_hold_sex  household_head_age  \
# 0                  36200         Female                  49
# 1                  29300           Male                  40
# 2                    425           Male                  39
# 3                    300           Male                  52
# 4                      0           Male                  65
#
#   house_hold_head_marital_status  \
# 0                         Single
# 1                        Married
# 2                        Married
# 3                        Married
# 4                        Married
#
#                        household_head_highest_grade  \
# 0  Teacher Training and Education Sciences Programs
# 1                       Transport Services Programs
# 2                                           Grade 3
# 3                               Elementary Graduate
# 4                               Elementary Graduate
#
#   household_head_job_business_indicator type_of_household  family_members  \
# 0                     With Job/Business   Extended Family               4
# 1                     With Job/Business     Single Family               3
# 2                     With Job/Business     Single Family               6
# 3                     With Job/Business     Single Family               3
# 4                     With Job/Business     Single Family               4
#
#    employed_family_members  tesda_accredited_institutions
# 0                        1                            100
# 1                        2                            100
# 2                        3                            100
# 3                        2                            100
# 4                        2                            100

# %%
income_df
# Out:
#       total_household_income region  total_food_expenditure  \
# 0                     480332    CAR                  117848
# 1                     198235    CAR                   67766
# 2                      82785    CAR                   61609
# 3                     107589    CAR                   78189
# 4                     189322    CAR                   94625
# ...                      ...    ...                     ...
# 5850                  396152    NCR                  151505
# 5851                  369677    NCR                  129728
# 5852                  358172    NCR                   95769
# 5853                  287135    NCR                   88197
# 5854                  381848    NCR                  136774
#
#            main_income_source  agricultural_indicator  tobacco_expenditure  \
# 0               Wage/Salaries                       0                    0
# 1               Wage/Salaries                       0                 2132
# 2               Wage/Salaries                       1                 4525
# 3               Wage/Salaries                       0                    0
# 4               Wage/Salaries                       0                    0
# ...                       ...                     ...                  ...
# 5850  Other sources of Income                       2                  724
# 5851  Other sources of Income                       2                    0
# 5852            Wage/Salaries                       2                    0
# 5853            Wage/Salaries                       2                 9050
# 5854            Wage/Salaries                       2                 1086
#
#       clothings_expenditure  housing_and_water_expenditure  \
# 0                      4607                          63636
# 1                      8230                          41370
# 2                      2735                          14340
# 3                      1390                          16638
# 4                      4620                          31122
# ...                     ...                            ...
# 5850                   3820                          70788
# 5851                   6310                          68550
# 5852                   5765                          85740
# 5853                   6055                         137238
# 5854                    820                          36450
#
#       medical_care_expenditure  education_expenditure house_hold_sex  \
# 0                         3457                  36200         Female
# 1                         3520                  29300           Male
# 2                           70                    425           Male
# 3                           60                    300           Male
# 4                          140                      0           Male
# ...                        ...                    ...            ...
# 5850                      6456                  10150         Female
# 5851                      1234                   1240         Female
# 5852                     19395                      0         Female
# 5853                       330                      0           Male
# 5854                     11294                   1900           Male
#
#       household_head_age house_hold_head_marital_status  \
# 0                     49                         Single
# 1                     40                        Married
# 2                     39                        Married
# 3                     52                        Married
# 4                     65                        Married
# ...                  ...                            ...
# 5850                  58                        Widowed
# 5851                  33                        Married
# 5852                  51                        Married
# 5853                  27                         Single
# 5854                  38                        Married
#
#                           household_head_highest_grade  \
# 0     Teacher Training and Education Sciences Programs
# 1                          Transport Services Programs
# 2                                              Grade 3
# 3                                  Elementary Graduate
# 4                                  Elementary Graduate
# ...                                                ...
# 5850                              High School Graduate
# 5851                               Second Year College
# 5852         Computing/Information Technology Programs
# 5853                               Second Year College
# 5854                              High School Graduate
#
#      household_head_job_business_indicator type_of_household  family_members  \
# 0                        With Job/Business   Extended Family               4
# 1                        With Job/Business     Single Family               3
# 2                        With Job/Business     Single Family               6
# 3                        With Job/Business     Single Family               3
# 4                        With Job/Business     Single Family               4
# ...                                    ...               ...             ...
# 5850                     With Job/Business   Extended Family               5
# 5851                     With Job/Business     Single Family               6
# 5852                     With Job/Business     Single Family               3
# 5853                     With Job/Business   Extended Family               2
# 5854                     With Job/Business   Extended Family              11
#
#       employed_family_members  tesda_accredited_institutions
# 0                           1                            100
# 1                           2                            100
# 2                           3                            100
# 3                           2                            100
# 4                           2                            100
# ...                       ...                            ...
# 5850                        0                            848
# 5851                        0                            848
# 5852                        1                            848
# 5853                        2                            848
# 5854                        3                            848
#
# [5855 rows x 19 columns]

# %% [markdown]
# ### multicolinearity

# %%
# assign to life_df_before to keep the cleaned data
life_df_before = life_df

# the VFI does expect a constant term in the data, so we need to add one using the add_constant method
X1 = sm.tools.add_constant(life_df_before)

# create the series for before
series_before = pd.Series([variance_inflation_factor(X1.values, i) for i in range(X1.shape[1])], index=X1.columns)

# display the series
display(series_before)

# %%
# Assign columns to X and Y
X = income_df.drop(['Total Household Income'], axis = 1)
Y = income_df[['Total Household Income']]

# Split X and y into X_
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=1)
